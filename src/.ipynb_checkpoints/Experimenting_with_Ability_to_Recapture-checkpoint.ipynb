# %%
# import pystan
import stanity
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
print('test')

# %%
from scipy.stats import norm, truncnorm

# %%
mu = 0
sigma = 1
n = 1000

data = norm(loc=mu,scale=sigma).rvs(n)

time_series = cumsum(data)
hist(data, bins=50)
figure()
plot(time_series)

model_code = """
data {
    int T; // number of time periods
    vector[T] Y; // value each time period
    
    real mu_prior_location;
    real mu_prior_scale;
    
    real sigma_prior_location;
    real sigma_prior_scale;
}

parameters {
    real mu;
    real<lower = 0> sigma;
    
}

model {
    mu ~ normal(mu_prior_location, mu_prior_scale);
    sigma ~ cauchy(sigma_prior_location, sigma_prior_scale);
    
    for(t in 1:(T-1)) {
        Y[t+1] ~ normal(mu+Y[t],sigma);
    }

}
"""

stan_data = {'T': len(time_series),
       'Y': time_series,
       'mu_prior_location': 3,
       'mu_prior_scale': 1,
       'sigma_prior_location': 0,
       'sigma_prior_scale': 2}

model_fit = stanity.fit(model_code, data=stan_data, n_jobs=1)
print(model_fit)
model_fit.plot()
tight_layout()
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_8e66b04252e7dda9281ce8f26cd55007 NOW.
# NOT reusing model.
# Ran in 49.761 sec.
# Inference for Stan model: anon_model_8e66b04252e7dda9281ce8f26cd55007.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu     -0.06  6.1e-4   0.03  -0.12  -0.08  -0.06  -0.04 2.8e-3   2645    1.0
# sigma   0.98  4.3e-4   0.02   0.94   0.97   0.98    1.0   1.03   2598    1.0
# lp__  -488.5    0.02   1.01 -491.1 -488.9 -488.2 -487.8 -487.5   2255    1.0
#
# Samples were drawn using NUTS at Fri Oct 28 16:15:34 2016.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
mu = 8
sigma = 2
n = 1000


a = -mu / sigma
data = truncnorm(a, inf, loc=mu,scale=sigma).rvs(n)

time_series = cumsum(data)
hist(data, bins=50)
figure()
plot(time_series)

model_code = """
functions {
  real lower_truncated_normal_lpdf(real x, real mu, real sigma, real A) {
    real out;
    if(x<=A) {
      out = log(0.0);
    } else {
      out = -log(sigma) + normal_lpdf(x| mu, sigma) - normal_lccdf(A | mu, sigma);
    }
    return(out);
  }
}
  
data {
    int T; // number of time periods
    vector[T] Y; // value each time period
    
    real mu_prior_location;
    real mu_prior_scale;
    
    real sigma_prior_location;
    real sigma_prior_scale;
}

parameters {
    real<lower=0> mu;
    real<lower = 0> sigma;
    
}

model {
    mu ~ normal(mu_prior_location, mu_prior_scale);
    sigma ~ cauchy(sigma_prior_location, sigma_prior_scale);
    
    for(t in 1:(T-1)) {
        target += lower_truncated_normal_lpdf( Y[t+1]-Y[t] | mu, sigma, 0.0);
    }

}
"""

stan_data = {'T': len(time_series),
       'Y': time_series,
       'mu_prior_location': 3,
       'mu_prior_scale': 1,
       'sigma_prior_location': 0,
       'sigma_prior_scale': 2}

model_fit = stanity.fit(model_code, data=stan_data, n_jobs=1)
print(model_fit)
model_fit.plot()
tight_layout()
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_ed78da2943ed9a83717975f3fb56f30f NOW.
# NOT reusing model.
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# C:\Users\jeff\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     383             try:
# --> 384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
#
# C:\Users\jeff\Anaconda3\lib\distutils\_msvccompiler.py in spawn(self, cmd)
#     502             os.environ['path'] = self._paths
# --> 503             return super().spawn(cmd)
#     504         finally:
#
# C:\Users\jeff\Anaconda3\lib\distutils\ccompiler.py in spawn(self, cmd)
#     908     def spawn(self, cmd):
# --> 909         spawn(cmd, dry_run=self.dry_run)
#     910
#
# C:\Users\jeff\Anaconda3\lib\distutils\spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      37     elif os.name == 'nt':
# ---> 38         _spawn_nt(cmd, search_path, dry_run=dry_run)
#      39     else:
#
# C:\Users\jeff\Anaconda3\lib\distutils\spawn.py in _spawn_nt(cmd, search_path, verbose, dry_run)
#      80             raise DistutilsExecError(
# ---> 81                   "command %r failed with exit status %d" % (cmd, rc))
#      82
#
# DistutilsExecError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# <ipython-input-30-9a5566b4365e> in <module>()
#      60        'sigma_prior_scale': 2}
#      61
# ---> 62 model_fit = stanity.fit(model_code, data=stan_data, n_jobs=1)
#      63 print(model_fit)
#      64 model_fit.plot()
#
# C:\Users\jeff\Anaconda3\lib\site-packages\stanity\fit.py in fit(model_code, *args, **kwargs)
#      35         print("NOT reusing model.")
#      36     start = time.time()
# ---> 37     FIT_CACHE[model_code] = pystan.stan(*args, **kwargs)
#      38     print("Ran in %0.3f sec." % (time.time() - start))
#      39     return FIT_CACHE[model_code]
#
# C:\Users\jeff\Anaconda3\lib\site-packages\pystan\api.py in stan(file, model_name, model_code, fit, data, pars, chains, iter, warmup, thin, init, seed, algorithm, control, sample_file, diagnostic_file, verbose, boost_lib, eigen_lib, n_jobs, **kwargs)
#     370         m = StanModel(file=file, model_name=model_name, model_code=model_code,
#     371                       boost_lib=boost_lib, eigen_lib=eigen_lib,
# --> 372                       verbose=verbose)
#     373     # check that arguments in kwargs are valid
#     374     valid_args = {"chain_id", "init_r", "test_grad", "append_samples", "enable_random_init",
#
# C:\Users\jeff\Anaconda3\lib\site-packages\pystan\model.py in __init__(self, file, charset, model_name, model_code, stanc_ret, boost_lib, eigen_lib, verbose, obfuscate_model_name, extra_compile_args)
#     308
#     309         try:
# --> 310             build_extension.run()
#     311         finally:
#     312             if redirect_stderr:
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     336
#     337         # Now actually compile and link everything.
# --> 338         self.build_extensions()
#     339
#     340     def check_extensions_list(self, extensions):
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in build_extensions(self)
#     445             self._build_extensions_parallel()
#     446         else:
# --> 447             self._build_extensions_serial()
#     448
#     449     def _build_extensions_parallel(self):
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in _build_extensions_serial(self)
#     470         for ext in self.extensions:
#     471             with self._filter_build_errors(ext):
# --> 472                 self.build_extension(ext)
#     473
#     474     @contextlib.contextmanager
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     530                                          debug=self.debug,
#     531                                          extra_postargs=extra_args,
# --> 532                                          depends=ext.depends)
#     533
#     534         # XXX outdated variable, kept here in case third-part code
#
# C:\Users\jeff\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
# --> 386                 raise CompileError(msg)
#     387
#     388         return objects
#
# CompileError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2

# %%
import pystan
model = pystan.StanModel(model_code=model_code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_f953009420ce0de23f3b41b60459f1c7 NOW.
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# C:\Users\jeff\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     383             try:
# --> 384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
#
# C:\Users\jeff\Anaconda3\lib\distutils\_msvccompiler.py in spawn(self, cmd)
#     502             os.environ['path'] = self._paths
# --> 503             return super().spawn(cmd)
#     504         finally:
#
# C:\Users\jeff\Anaconda3\lib\distutils\ccompiler.py in spawn(self, cmd)
#     908     def spawn(self, cmd):
# --> 909         spawn(cmd, dry_run=self.dry_run)
#     910
#
# C:\Users\jeff\Anaconda3\lib\distutils\spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      37     elif os.name == 'nt':
# ---> 38         _spawn_nt(cmd, search_path, dry_run=dry_run)
#      39     else:
#
# C:\Users\jeff\Anaconda3\lib\distutils\spawn.py in _spawn_nt(cmd, search_path, verbose, dry_run)
#      80             raise DistutilsExecError(
# ---> 81                   "command %r failed with exit status %d" % (cmd, rc))
#      82
#
# DistutilsExecError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# <ipython-input-8-3fabdc6c38c7> in <module>()
#       1 import pystan
# ----> 2 model = pystan.StanModel(model_code=model_code)
#
# C:\Users\jeff\Anaconda3\lib\site-packages\pystan\model.py in __init__(self, file, charset, model_name, model_code, stanc_ret, boost_lib, eigen_lib, verbose, obfuscate_model_name, extra_compile_args)
#     308
#     309         try:
# --> 310             build_extension.run()
#     311         finally:
#     312             if redirect_stderr:
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     336
#     337         # Now actually compile and link everything.
# --> 338         self.build_extensions()
#     339
#     340     def check_extensions_list(self, extensions):
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in build_extensions(self)
#     445             self._build_extensions_parallel()
#     446         else:
# --> 447             self._build_extensions_serial()
#     448
#     449     def _build_extensions_parallel(self):
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in _build_extensions_serial(self)
#     470         for ext in self.extensions:
#     471             with self._filter_build_errors(ext):
# --> 472                 self.build_extension(ext)
#     473
#     474     @contextlib.contextmanager
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     530                                          debug=self.debug,
#     531                                          extra_postargs=extra_args,
# --> 532                                          depends=ext.depends)
#     533
#     534         # XXX outdated variable, kept here in case third-part code
#
# C:\Users\jeff\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
# --> 386                 raise CompileError(msg)
#     387
#     388         return objects
#
# CompileError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2

# %%
mu = 4
sigma = 2
n = 10000


a = -mu / sigma
data = truncnorm(a, inf, loc=mu,scale=sigma).rvs(n)

time_series = cumsum(data)
hist(data, bins=50)
figure()
plot(time_series)

print(mean(data))
print(std(data))

model_code = """
data {
    int N; // number of time periods
    real<lower=0> Y[N]; // value each time period
    
    real mu_prior_location;
    real mu_prior_scale;
    
    real sigma_prior_location;
    real sigma_prior_scale;
}

parameters {
    real<lower=0> mu;
    real<lower=0> sigma;
    
}

model {
    mu ~ normal(mu_prior_location, mu_prior_scale);
    sigma ~ cauchy(sigma_prior_location, sigma_prior_scale);
    
    for(n in 1:(N-1)) {
        Y[n] ~ normal(mu, sigma) T[0,];
    }

}
"""

stan_data = {'N': len(data),
       'Y': data,
       'mu_prior_location': 3,
       'mu_prior_scale': 1,
       'sigma_prior_location': 0,
       'sigma_prior_scale': 2}

model_fit = stanity.fit(model_code, data=stan_data, n_jobs=1)
print(model_fit)
model_fit.plot()
tight_layout()
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_f953009420ce0de23f3b41b60459f1c7 NOW.
# 4.12472903396
# 1.89766266909
# NOT reusing model.
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# C:\Users\jeff\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     383             try:
# --> 384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
#
# C:\Users\jeff\Anaconda3\lib\distutils\_msvccompiler.py in spawn(self, cmd)
#     502             os.environ['path'] = self._paths
# --> 503             return super().spawn(cmd)
#     504         finally:
#
# C:\Users\jeff\Anaconda3\lib\distutils\ccompiler.py in spawn(self, cmd)
#     908     def spawn(self, cmd):
# --> 909         spawn(cmd, dry_run=self.dry_run)
#     910
#
# C:\Users\jeff\Anaconda3\lib\distutils\spawn.py in spawn(cmd, search_path, verbose, dry_run)
#      37     elif os.name == 'nt':
# ---> 38         _spawn_nt(cmd, search_path, dry_run=dry_run)
#      39     else:
#
# C:\Users\jeff\Anaconda3\lib\distutils\spawn.py in _spawn_nt(cmd, search_path, verbose, dry_run)
#      80             raise DistutilsExecError(
# ---> 81                   "command %r failed with exit status %d" % (cmd, rc))
#      82
#
# DistutilsExecError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# <ipython-input-4-47411a6706fa> in <module>()
#      51        'sigma_prior_scale': 2}
#      52
# ---> 53 model_fit = stanity.fit(model_code, data=stan_data, n_jobs=1)
#      54 print(model_fit)
#      55 model_fit.plot()
#
# C:\Users\jeff\Anaconda3\lib\site-packages\stanity\fit.py in fit(model_code, *args, **kwargs)
#      35         print("NOT reusing model.")
#      36     start = time.time()
# ---> 37     FIT_CACHE[model_code] = pystan.stan(*args, **kwargs)
#      38     print("Ran in %0.3f sec." % (time.time() - start))
#      39     return FIT_CACHE[model_code]
#
# C:\Users\jeff\Anaconda3\lib\site-packages\pystan\api.py in stan(file, model_name, model_code, fit, data, pars, chains, iter, warmup, thin, init, seed, algorithm, control, sample_file, diagnostic_file, verbose, boost_lib, eigen_lib, n_jobs, **kwargs)
#     370         m = StanModel(file=file, model_name=model_name, model_code=model_code,
#     371                       boost_lib=boost_lib, eigen_lib=eigen_lib,
# --> 372                       verbose=verbose)
#     373     # check that arguments in kwargs are valid
#     374     valid_args = {"chain_id", "init_r", "test_grad", "append_samples", "enable_random_init",
#
# C:\Users\jeff\Anaconda3\lib\site-packages\pystan\model.py in __init__(self, file, charset, model_name, model_code, stanc_ret, boost_lib, eigen_lib, verbose, obfuscate_model_name, extra_compile_args)
#     308
#     309         try:
# --> 310             build_extension.run()
#     311         finally:
#     312             if redirect_stderr:
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     336
#     337         # Now actually compile and link everything.
# --> 338         self.build_extensions()
#     339
#     340     def check_extensions_list(self, extensions):
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in build_extensions(self)
#     445             self._build_extensions_parallel()
#     446         else:
# --> 447             self._build_extensions_serial()
#     448
#     449     def _build_extensions_parallel(self):
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in _build_extensions_serial(self)
#     470         for ext in self.extensions:
#     471             with self._filter_build_errors(ext):
# --> 472                 self.build_extension(ext)
#     473
#     474     @contextlib.contextmanager
#
# C:\Users\jeff\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     530                                          debug=self.debug,
#     531                                          extra_postargs=extra_args,
# --> 532                                          depends=ext.depends)
#     533
#     534         # XXX outdated variable, kept here in case third-part code
#
# C:\Users\jeff\Anaconda3\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     384                 self.spawn(args)
#     385             except DistutilsExecError as msg:
# --> 386                 raise CompileError(msg)
#     387
#     388         return objects
#
# CompileError: command 'C:\\Program Files (x86)\\Microsoft Visual Studio 14.0\\VC\\BIN\\x86_amd64\\cl.exe' failed with exit status 2

# %%
model_code = """
functions {
  real lower_truncated_normal_lpdf(real x, real mu, real sigma, real A) {
    real out;
    if(x<=A) {
      out = log(0.0);
    } else {
      out = -log(sigma) + normal_lpdf(x| mu, sigma) - normal_lccdf(A | mu, sigma);
    }
    return(out);
  }
}
  
data {
    int T; // number of time periods
    vector[T] Y; // value each time period
    
    real mu_prior_location;
    real mu_prior_scale;
    
    real sigma_prior_location;
    real sigma_prior_scale;
}

parameters {
    real<lower=0> mu;
    real<lower = 0> sigma;
    
}

model {
    mu ~ normal(mu_prior_location, mu_prior_scale);
    sigma ~ cauchy(sigma_prior_location, sigma_prior_scale);
    
    for(t in 1:(T-1)) {
        target += lower_truncated_normal_lpdf( Y[t+1]-Y[t] | mu, sigma, 0.0);
    }

}
"""

model = pystan.StanModel(model_code=model_code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_ed78da2943ed9a83717975f3fb56f30f NOW.

# %%
mu = 8
sigma = 2
n = 1000


a = -mu / sigma
data = truncnorm(a, inf, loc=mu,scale=sigma).rvs(n)

time_series = cumsum(data)
hist(data, bins=50)
figure()
plot(time_series)

stan_data = {'T': len(time_series),
       'Y': time_series,
       'mu_prior_location': 1,
       'mu_prior_scale': 1,
       'sigma_prior_location': 2,
       'sigma_prior_scale': 2}

fit = model.sampling(stan_data)
print(fit)
# Out:
# Inference for Stan model: anon_model_ed78da2943ed9a83717975f3fb56f30f.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu      7.93  8.5e-4   0.04   7.84    7.9   7.93   7.96   8.02   2562    1.0
# sigma   1.39  4.4e-4   0.02   1.35   1.38   1.39   1.41   1.43   2396    1.0
# lp__   -2598    0.02   0.99  -2601  -2599  -2598  -2598  -2597   2320    1.0
#
# Samples were drawn using NUTS at Fri Oct 28 08:56:44 2016.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
model_code = """
functions {
  real lower_truncated_normal_lpdf(real x, real mu, real sigma, real A) {
    real out;
    if(x<=A) {
      out = log(0.0);
    } else {
      out = -log(sigma) + normal_lpdf(x| mu, sigma) - normal_lccdf(A | mu, sigma);
    }
    return(out);
  }
}
  
data {
    int T; // number of time periods
    real<lower=0> Y[T]; // value each time period
    
    real mu_prior_location;
    real mu_prior_scale;
    
    real sigma_prior_location;
    real sigma_prior_scale;
}

parameters {
    real<lower=0> mu;
    real<lower = 0> sigma;
    
}

model {
    mu ~ normal(mu_prior_location, mu_prior_scale);
    sigma ~ cauchy(sigma_prior_location, sigma_prior_scale);
    
    for(t in 1:T) {
        target += lower_truncated_normal_lpdf( Y[t] | mu, sigma, 0.0);
    }

}
"""

model = pystan.StanModel(model_code=model_code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_a568e172aac7a7d42f1d1d151a005c5e NOW.

# %%
mu = 8
sigma = 2
n = 1000


a = -mu / sigma
data = truncnorm(a, inf, loc=mu,scale=sigma).rvs(n)

time_series = cumsum(data)
hist(data, bins=50)
figure()
plot(time_series)

stan_data = {'T': len(data),
       'Y': data,
       'mu_prior_location': 1,
       'mu_prior_scale': 1,
       'sigma_prior_location': 2,
       'sigma_prior_scale': 2}

fit = model.sampling(stan_data)
print(fit)
# Out:
# Inference for Stan model: anon_model_a568e172aac7a7d42f1d1d151a005c5e.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu      8.02  9.1e-4   0.05   7.93   7.99   8.02   8.05   8.11   2545    1.0
# sigma   1.47  4.7e-4   0.02   1.43   1.46   1.47   1.49   1.52   2421    1.0
# lp__   -2717    0.02   0.99  -2720  -2717  -2717  -2716  -2716   2119    1.0
#
# Samples were drawn using NUTS at Fri Oct 28 09:01:51 2016.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
model_code = """
functions {
  real lower_truncated_normal_lpdf(real x, real mu, real sigma, real A) {
    real out;
    if(x<=A) {
      out = log(0.0);
    } else {
      out = -log(sigma) + normal_lpdf(x| mu, sigma) - normal_lccdf(A | mu, sigma);
    }
    return(out);
  }
}
  
data {
    int T; // number of time periods
    real<lower=0> Y[T]; // value each time period
    
    real mu_prior_location;
    real mu_prior_scale;
    
    real sigma_prior_location;
    real sigma_prior_scale;
}

parameters {
    real<lower=0> mu;
    real<lower = 0> sigma;
    
}

model {
    mu ~ normal(mu_prior_location, mu_prior_scale);
    sigma ~ cauchy(sigma_prior_location, sigma_prior_scale);
    
    for(t in 1:T) {
        target += normal_lpdf(Y[t]| mu, sigma);
    }

}
"""

model = pystan.StanModel(model_code=model_code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_582bf1defc55fa561a48285fe570cd9a NOW.

# %%
mu = 8
sigma = 2
n = 1000


a = -mu / sigma
data = truncnorm(a, inf, loc=mu,scale=sigma).rvs(n)

time_series = cumsum(data)
hist(data, bins=50)
figure()
plot(time_series)

stan_data = {'T': len(data),
       'Y': data,
       'mu_prior_location': 1,
       'mu_prior_scale': 1,
       'sigma_prior_location': 2,
       'sigma_prior_scale': 2}

fit = model.sampling(stan_data)
print(fit)
# Out:
# Inference for Stan model: anon_model_582bf1defc55fa561a48285fe570cd9a.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#         mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu      8.02  1.3e-3   0.06    7.9   7.98   8.03   8.07   8.15   2391    1.0
# sigma   1.93  8.5e-4   0.04   1.85    1.9   1.93   1.96   2.02   2495    1.0
# lp__   -2097    0.02   1.03  -2099  -2097  -2096  -2096  -2096   1734    1.0
#
# Samples were drawn using NUTS at Fri Oct 28 09:02:43 2016.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %% [markdown]
# The problem is in our custom-made truncated normal. I suspect the problem is in the normal_lccdf, which should be a constant given a particular mu and sigma but I think Stan may be treating it otherwise. If we could calculate that directly then we may fix it?

# %%
theta = .5
mu = 5
sigma = 2
n = 1000

improvement = rand(n)>theta

a = -mu / sigma
data = truncnorm(a, inf, loc=mu,scale=sigma).rvs(n)
data[~improvement]=0

time_series = cumsum(data)
hist(data, bins=50)
figure()
plot(time_series)
